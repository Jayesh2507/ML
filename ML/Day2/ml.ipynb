# %%
import pandas as pd

# %%
df1 = pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8],"C":[11,12,13,14]})

# %%
df1
# Out:
#    A  B   C
# 0  1  5  11
# 1  2  6  12
# 2  3  7  13
# 3  4  8  14

# %%
df = pd.read_csv('Z:\ML\Computer_Shop.csv')

# %%
df
# Out:
#      0         1          2         3         4    5 Unnamed: 6
# 0    0  Computer  Antivirus  Pendrive  HardDisk  SSD    Speaker
# 1    1  Computer        NaN  Pendrive  HardDisk  SSD        NaN
# 2    2       NaN        NaN  Pendrive  HardDisk  SSD        NaN
# 3    3       NaN  Antivirus       NaN       NaN  NaN    Speaker
# 4    4  Computer  Antivirus  Pendrive  HardDisk  SSD    Speaker
# 5    5  Computer  Antivirus       NaN       NaN  SSD        NaN
# 6    6  Computer  Antivirus  Pendrive  HardDisk  NaN    Speaker
# 7    7  Computer  Antivirus       NaN       NaN  SSD        NaN
# 8    8  Computer        NaN  Pendrive       NaN  NaN    Speaker
# 9    9  Computer        NaN  Pendrive  HardDisk  SSD        NaN
# 10  10       NaN  Antivirus  Pendrive  HardDisk  NaN    Speaker
# 11  11  Computer        NaN       NaN  HardDisk  SSD    Speaker
# 12  12  Computer  Antivirus  Pendrive  HardDisk  SSD        NaN
# 13  13  Computer        NaN  Pendrive       NaN  SSD    Speaker
# ...

# %%
df.head(10)
# Out:
#    0         1          2         3         4    5 Unnamed: 6
# 0  0  Computer  Antivirus  Pendrive  HardDisk  SSD    Speaker
# 1  1  Computer        NaN  Pendrive  HardDisk  SSD        NaN
# 2  2       NaN        NaN  Pendrive  HardDisk  SSD        NaN
# 3  3       NaN  Antivirus       NaN       NaN  NaN    Speaker
# 4  4  Computer  Antivirus  Pendrive  HardDisk  SSD    Speaker
# 5  5  Computer  Antivirus       NaN       NaN  SSD        NaN
# 6  6  Computer  Antivirus  Pendrive  HardDisk  NaN    Speaker
# 7  7  Computer  Antivirus       NaN       NaN  SSD        NaN
# 8  8  Computer        NaN  Pendrive       NaN  NaN    Speaker
# 9  9  Computer        NaN  Pendrive  HardDisk  SSD        NaN

# %%
df.tail(10)
# Out:
#      0         1          2         3         4    5 Unnamed: 6
# 31  31  Computer        NaN  Pendrive  HardDisk  SSD    Speaker
# 32  32       NaN  Antivirus  Pendrive  HardDisk  SSD    Speaker
# 33  33       NaN  Antivirus       NaN  HardDisk  SSD    Speaker
# 34  34  Computer  Antivirus  Pendrive  HardDisk  SSD    Speaker
# 35  35  Computer        NaN  Pendrive  HardDisk  SSD    Speaker
# 36  36  Computer  Antivirus  Pendrive       NaN  SSD    Speaker
# 37  37       NaN  Antivirus       NaN       NaN  NaN        NaN
# 38  38  Computer  Antivirus       NaN       NaN  SSD        NaN
# 39  39  Computer  Antivirus  Pendrive  HardDisk  NaN    Speaker
# 40  40  Computer  Antivirus       NaN       NaN  SSD        NaN

# %%
df.shape
# Out:
# (41, 7)

# %%
df.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', 'Unnamed: 6'], dtype='object')

# %%
df2 = pd.read_csv("Z:\ML\Company_data.csv")

# %%
df2
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df2.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df2.shape
# Out:
# (200, 4)
